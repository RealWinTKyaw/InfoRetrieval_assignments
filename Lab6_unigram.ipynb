# %%
import re
import math
import numpy as np
import copy

# used for unseen words in training vocabularies
UNK = None
# sentence start and end
SENTENCE_START = "<s>"
SENTENCE_END = "</s>"

# %%
def read_sentences_from_file(file_path):
    '''
        read the files.
    '''
    with open(file_path, "r") as f:
        return [re.split("\s+", line.rstrip('\n')) for line in f]

# %%
class UnigramLanguageModel:
    def __init__(self, sentences, mode="collection", smoothing=False):

        '''
        if term not in vocab, just assign it as 'unknown', add it to vocab and normalize accordingly
            sentences: sentences of the dataset
            mode: whether this language model is for the whole corpus/collection or just a single document
            smoothing: add-one smoothing
        '''
        self.valid_modes = ['document', 'collection']
        self.smoothing = smoothing
        self.mode = None
        
        if mode not in self.valid_modes:
            print("Please use these modes:", self.valid_modes)
        else:
            self.mode = mode
            
        vocab = read_sentences_from_file('./train.vocab.txt')
        self.size_of_vocab = len(vocab)
        self.vocab = {term[0]: 0 for term in vocab}
        #self.vocab[UNK] = 0
        self.total_terms = 0
        
        for sentence in sentences:
            for term in sentence:
                if term == SENTENCE_START or term == SENTENCE_END:
                    continue
                else:
                    self.vocab[term] += 1
                    self.total_terms += 1
            
    def calculate_unigram_probability(self, word):
        '''
            calculate unigram probability of a word
        '''
        numerator = self.vocab.get(word, 0)
        denominator = self.total_terms
            
        if self.smoothing and numerator==0:
            numerator += 1
            denominator += (self.size_of_vocab + 1)
            
        if not self.smoothing and numerator==0:
            numerator += 1
            denominator += 1
            
        return numerator/denominator
    
    def calculate_sentence_probability(self, sentence, normalize_probability=True):
        '''
            calculate score/probability of a sentence or query using the unigram language model.
            sentence: input sentence or query
            normalize_probability: If true then log of probability is not computed. Otherwise take log2 of the probability score.
        '''
        if not self.mode:
            print('Wrong mode used')
            return
        
        result = 1
        for word in sentence:
            if word == SENTENCE_START or word == SENTENCE_END:
                continue
            result *= self.calculate_unigram_probability(word)
            
        if not normalize_probability:
            result = math.log2(result)
            
        return result

# %%
def calculate_interpolated_sentence_probability(sentence, doc, collection, alpha=0.75, normalize_probability=True):
    '''
        calculate interpolated sentence/query probability using both sentence and collection unigram models.
        sentence: input sentence/query
        doc: unigram language model a doc. HINT: this can be an instance of the UnigramLanguageModel class
        collection: unigram language model a collection. HINT: this can be an instance of the UnigramLanguageModel class
        alpha: the hyperparameter to combine the two probability scores coming from the document and collection language models.
        normalize_probability: If true then log of probability is not computed. Otherwise take log2 of the probability score.
    '''
    result = alpha*doc.calculate_sentence_probability(sentence, normalize_probability) + (1-alpha)*collection.calculate_sentence_probability(sentence, normalize_probability)
    
    return result

# %%
# first read the datasets
actual_dataset = read_sentences_from_file("./train.txt")
doc1_dataset = read_sentences_from_file("./doc1.txt")
doc2_dataset = read_sentences_from_file("./doc2.txt")
doc3_dataset = read_sentences_from_file("./doc3.txt")
actual_dataset_test = read_sentences_from_file("./test.txt")

'''
    Question: for each of the test queries given in test.txt, find out best matching document/doc
    according to their interpolated sentence probability.
    Optional: Extend the model to bigram language modeling.
'''
DOC_MODE = 'document'
COL_MODE = 'collection'

# with smoothing
doc1_model = UnigramLanguageModel(doc1_dataset, mode=DOC_MODE, smoothing=True)
doc2_model = UnigramLanguageModel(doc2_dataset, mode=DOC_MODE, smoothing=True)
doc3_model = UnigramLanguageModel(doc3_dataset, mode=DOC_MODE, smoothing=True)
models = [doc1_model, doc2_model, doc3_model]
collection = UnigramLanguageModel(actual_dataset, mode=COL_MODE, smoothing=True)

for query in actual_dataset_test:
    print('Query:', query)
    best_doc = None
    current_score = -np.inf
    for model in models:
        new_score = model.calculate_sentence_probability(query)
        print(new_score)
        if new_score > current_score:
            current_score = new_score
            best_doc = models.index(model)
    print('The best matching document is document', best_doc+1, 'with a probability of', current_score, '\n')
# Out:
# Query: ['<s>', 'the', 'website', 'and', 'monthly', 'newsletter', 'is', 'run', 'by', 'a', 'sub-committee', 'that', 'is', 'independent', 'to', 'the', 'parish', 'council', 'and', 'is', 'financed', 'through', 'selling', 'advertisement', 'space', 'to', 'local', 'businesses', '</s>']
# 1.4561353824759197e-81
# 2.0662569510312752e-75
# 2.0710835876900276e-74
# The best matching document is document 3 with a probability of 2.0710835876900276e-74
#
# Query: ['<s>', 'uk', 'was', 'designed', 'and', 'built', 'by', 'chris', 'chambers', 'the', 'site', 'is', 'designed', 'in', 'a', 'way', 'that', 'when', 'content', 'is', 'added', 'to', 'the', 'site', 'no', 'previous', 'content', 'needs', 'to', 'be', 'edited', 'therefore', 'creating', 'a', 'archive', 'over', 'time', 'meaning', 'that', 'every', 'single', 'article', 'that', 'is', 'added', 'is', 'stored', 'and', 'never', 'deleted', 'allowing', 'users', 'to', 'search', 'and', 'read', 'articles', 'going', 'far', 'back', 'as', 'the', 'website', 'launch', 'date', '</s>']
# 7.41053115266956e-198
# 3.9061200298992615e-190
# 3.1352418766146685e-188
# The best matching document is document 3 with a probability of 3.1352418766146685e-188
#
# Query: ['<s>', 'chelmondiston', 'is', 'a', 'small', 'village', 'and', 'civil', 'parish', 'in', 'suffolk', 'england', 'on', 'the', 'south', 'bank', 'of', 'the', 'river', 'orwell', 'and', 'num', 'miles', 'south-east', 'of', 'ipswich', '</s>']
# 5.906709985611285e-70
# 5.168322054561553e-72
# 9.152118374002234e-69
# The best matching document is document 3 with a probability of 9.152118374002234e-69
#
# Query: ['<s>', 'formerly', 'known', 'as', 'chelmington', 'and', 'was', 'in', 'the', 'old', 'hundreds', 'of', 'suffolk', 'of', 'babergh', '</s>']
# 3.709159591244114e-38
# 9.86587136594052e-38
# 1.50748926291767e-35
# The best matching document is document 3 with a probability of 1.50748926291767e-35
#
# Query: ['<s>', 'the', 'former', 'church', 'site', 'has', 'not', 'been', 'a', 'very', 'lucky', 'one', '</s>']
# 6.594061495545093e-35
# 8.340918245012823e-34
# 4.336500146839598e-35
# The best matching document is document 2 with a probability of 8.340918245012823e-34
#
# Query: ['<s>', 'one', 'night', 'in', 'late', 'num', 'a', 'v2', 'rocket', 'hit', 'hakewill', 'church', 'build', 'work', 'and', 'the', 'little', 'church', 'was', 'almost', 'completely', 'destroyed', '</s>']
# 4.0575159794492464e-63
# 7.92410518372808e-68
# 4.057794254457086e-63
# The best matching document is document 3 with a probability of 4.057794254457086e-63
#
# Query: ['<s>', 'it', 'was', 'not', 'until', 'num', 'that', 'basil', 'hatcher', 'was', 'given', 'the', 'commission', 'to', 'provide', 'a', 'replacement', 'st', 'andrew', 'church', '</s>']
# 9.465738453297347e-56
# 2.061291249665828e-56
# 1.2865827708735418e-54
# The best matching document is document 3 with a probability of 1.2865827708735418e-54
#
# Query: ['<s>', 'the', 'church', 'includes', 'a', 'fine', 'set', 'of', 'stained', 'glass', 'windows', 'the', 'num', 'work', 'of', 'francis', 'skeat', '</s>']
# 7.949709568912622e-45
# 5.3940352587924266e-48
# 2.1831971575642295e-44
# The best matching document is document 3 with a probability of 2.1831971575642295e-44
#
# Query: ['<s>', 'there', 'is', 'a', 'newer', 'methodist', 'church', 'on', 'the', 'main', 'road', 'and', 'a', 'baptist', 'on', 'pin', 'mill', 'road', '</s>']
# 3.7862953813189394e-53
# 3.098277406382714e-50
# 7.07517597358778e-48
# The best matching document is document 3 with a probability of 7.07517597358778e-48
#
# Query: ['<s>', 'pubs', 'in', 'the', 'area', 'include', 'the', 'butt', 'and', 'oyster', 'and', 'the', 'red', 'lion', '</s>']
# 4.976455784919187e-34
# 5.402112676817212e-35
# 1.3584877217814305e-33
# The best matching document is document 3 with a probability of 1.3584877217814305e-33
#
# Query: ['<s>', 'dinan', 'gallo', 'dinan', 'is', 'a', 'walled', 'breton', 'town', 'and', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'north-western', 'france', '</s>']
# 2.3664346133243362e-56
# 1.1594763279370273e-56
# 1.530145519824714e-55
# The best matching document is document 3 with a probability of 1.530145519824714e-55
#
# Query: ['<s>', 'its', 'geographical', 'setting', 'is', 'exceptional', '</s>']
# 2.2967910650374956e-17
# 1.430102497612372e-15
# 1.3200049191197719e-15
# The best matching document is document 2 with a probability of 1.430102497612372e-15
#
# Query: ['<s>', 'instead', 'of', 'nestling', 'on', 'the', 'valley', 'floor', 'like', 'morlaix', 'most', 'urban', 'development', 'has', 'been', 'on', 'the', 'hillside', 'overlooking', 'the', 'river', 'rance', '</s>']
# 3.4569259732297434e-67
# 8.188218667238885e-62
# 1.8466739320116142e-64
# The best matching document is document 2 with a probability of 8.188218667238885e-62
#
# Query: ['<s>', 'the', 'area', 'alongside', 'the', 'river', 'rance', 'is', 'known', 'as', 'the', 'port', 'of', 'dinan', 'and', 'is', 'connected', 'to', 'the', 'town', 'by', 'the', 'steep', 'streets', 'rue', 'jerzual', 'and', 'its', 'continuation', 'outside', 'the', 'walls', 'the', 'rue', 'de', 'petit', 'fort', 'this', 'river', 'has', 'moderate', 'turbidity', 'and', 'its', 'brownish', 'water', 'is', 'somewhat', 'low', 'in', 'velocity', 'due', 'to', 'the', 'slight', 'gradient', 'of', 'the', 'watercourse', 'ph', 'levels', 'have', 'been', 'measured', 'at', 'within', 'the', 'city', 'of', 'dinan', 'and', 'electrical', 'conductivity', 'of', 'the', 'waters', 'have', 'tested', 'at', 'num', 'micro-siemens', 'per', 'centimetre', '</s>']
# 4.545470499988602e-242
# 3.321084016487026e-234
# 1.4100518708768946e-225
# The best matching document is document 3 with a probability of 1.4100518708768946e-225
#
# Query: ['<s>', 'in', 'the', 'center', 'of', 'dinan', 'the', 'rance', 'summer', 'flows', 'are', 'typically', 'in', 'the', 'range', 'of', 'num', 'cubic', 'feet', 'per', 'second', '</s>']
# 7.763388250891236e-51
# 6.809322643675855e-58
# 1.1579244937861878e-52
# The best matching document is document 1 with a probability of 7.763388250891236e-51
#
# Query: ['<s>', 'for', 'many', 'years', 'the', 'bridge', 'over', 'the', 'river', 'rance', 'at', 'dinan', 'was', 'the', 'most', 'northerly', 'crossing', 'point', 'on', 'the', 'river', 'but', 'the', 'tidal', 'power', 'station', 'at', 'the', 'mouth', 'of', 'the', 'estuary', 'constructed', 'in', 'the', 'num', 'downstream', 'from', 'dinan', 'incorporates', 'a', 'num', 'meter', 'long', 'tidal', 'barrage', 'which', 'doubles', 'as', 'a', 'crossing', 'point', 'nearer', 'to', 'the', 'sea', '</s>']
# 2.8903692830501836e-163
# 2.8574129464860715e-159
# 6.175311419790389e-154
# The best matching document is document 3 with a probability of 6.175311419790389e-154
#
# Query: ['<s>', 'the', 'medieval', 'town', 'on', 'the', 'hilltop', 'has', 'many', 'fine', 'old', 'buildings', 'some', 'as', 'early', 'as', 'num', 'century', '</s>']
# 2.0774481814780124e-55
# 1.549138703191356e-50
# 2.3850839689966174e-51
# The best matching document is document 2 with a probability of 1.549138703191356e-50
#
# Query: ['<s>', 'the', 'town', 'retains', 'a', 'large', 'section', 'of', 'the', 'city', 'walls', 'part', 'of', 'which', 'can', 'be', 'walked', 'around', '</s>']
# 6.815331686374089e-51
# 3.502620297917161e-50
# 8.89286011227792e-48
# The best matching document is document 3 with a probability of 8.89286011227792e-48
#
# Query: ['<s>', 'major', 'historical', 'attractions', 'include', 'the', 'jacobins', 'theatre', 'dating', 'from', 'num', 'the', 'flamboyant', 'gothic', 'st', 'malo', 'church', 'the', 'romanesque', 'st', 'saviour', 'basilica', 'duchess', 'anne', 'tower', 'and', 'the', 'cents', 'teau', 'de', 'dinan', '</s>']
# 1.174407799979796e-95
# 7.875819961154221e-97
# 2.0021049321583541e-91
# The best matching document is document 3 with a probability of 2.0021049321583541e-91
#
# Query: ['<s>', 'a', 'major', 'highlight', 'in', 'the', 'calendar', 'is', 'dinan', 'te', 'des', 'remparts', '</s>']
# 1.4421768864695803e-30
# 1.000910189401539e-32
# 2.1292215720982427e-32
# The best matching document is document 1 with a probability of 1.4421768864695803e-30
#
# Query: ['<s>', 'the', 'town', 'is', 'transformed', 'with', 'decoration', 'and', 'many', 'locals', 'dress', 'up', 'in', 'medieval', 'garb', 'for', 'this', 'two-day', 'festival', '</s>']
# 1.567824174459188e-56
# 4.7383932601693203e-54
# 2.0869484728720408e-53
# The best matching document is document 3 with a probability of 2.0869484728720408e-53
#
# Query: ['<s>', 'it', 'occurs', 'only', 'every', 'other', 'year', '</s>']
# 1.7225932987781217e-18
# 2.2894279030998897e-21
# 2.1901434275115366e-21
# The best matching document is document 1 with a probability of 1.7225932987781217e-18
#
# Query: ['<s>', 'inhabitants', 'of', 'dinan', 'are', 'called', 'dinannais', '</s>']
# 1.7225932987781217e-18
# 4.37429393641631e-19
# 1.8562569175121788e-17
# The best matching document is document 3 with a probability of 1.8562569175121788e-17
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 2.307483018351329e-29
# 2.2520479261534624e-32
# 1.960214609812945e-30
# The best matching document is document 1 with a probability of 2.307483018351329e-29
#
# Query: ['<s>', 'dinan', 'was', 'also', 'a', 'favorite', 'place', 'for', 'artists', 'to', 'visit', 'in', 'search', 'of', 'picturesque', 'views', '</s>']
# 1.0599612758550165e-45
# 2.6323522534560666e-44
# 7.146332029093577e-43
# The best matching document is document 3 with a probability of 7.146332029093577e-43
#
# Query: ['<s>', 'the', 'british', 'artist', 'john', 'everett', 'millais', 'lived', 'there', 'as', 'a', 'child', '</s>']
# 1.092184098641009e-36
# 2.619293249861286e-35
# 8.673000293679197e-35
# The best matching document is document 3 with a probability of 8.673000293679197e-35
#
# Query: ['<s>', 'it', 'was', 'also', 'painted', 'by', 'edward', 'ward', 'and', 'horace', 'tuck', 'among', 'others', '</s>']
# 3.9811646279353506e-35
# 4.252099431592998e-38
# 1.0303971835667747e-39
# The best matching document is document 1 with a probability of 3.9811646279353506e-35
#
# Query: ['<s>', 'guingamp', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'brittany', 'in', 'north-western', 'france', '</s>']
# 1.0303221086789209e-39
# 7.745433270569132e-40
# 2.7103125917747493e-39
# The best matching document is document 3 with a probability of 2.7103125917747493e-39
#
# Query: ['<s>', 'inhabitants', 'of', 'guingamp', 'are', 'called', 'guingampais', '</s>']
# 1.7225932987781217e-18
# 4.37429393641631e-19
# 1.8562569175121788e-17
# The best matching document is document 3 with a probability of 1.8562569175121788e-17
#
# Query: ['<s>', 'the', 'municipality', 'launched', 'a', 'linguistic', 'plan', 'through', 'ya', 'brezhoneg', 'on', 'num', 'july', 'num', '</s>']
# 2.730460246602522e-39
# 1.0891387269594511e-42
# 1.6939453698592184e-39
# The best matching document is document 1 with a probability of 2.730460246602522e-39
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'the', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 2.8843537729391613e-30
# 2.3397900531464548e-33
# 2.450268262266181e-31
# The best matching document is document 1 with a probability of 2.8843537729391613e-30
#
# Query: ['<s>', 'the', 'breton', 'dance', 'festival', 'of', 'saint-loup', 'is', 'held', 'every', 'year', 'in', 'mid-august', '</s>']
# 1.791524082570907e-33
# 1.949825044288712e-34
# 3.9922904476842065e-34
# The best matching document is document 1 with a probability of 1.791524082570907e-33
#
# Query: ['<s>', 'then', 'there', 'is', 'the', 'annual', 'which', 'brings', 'pilgrims', 'to', 'pay', 'homage', 'to', 'the', 'black', 'in', 'the', 'basilica', 'of', 'notre', 'dame', 'de', 'bon', 'secours', '</s>']
# 1.0802893666342947e-70
# 2.0817064046708042e-65
# 2.550141282987287e-64
# The best matching document is document 3 with a probability of 2.550141282987287e-64
#
# Query: ['<s>', 'guingamp', 'is', 'home', 'to', 'the', 'num', 'coupe', 'de', 'france', 'holders', 'en', 'avant', 'de', 'guingamp', 'a', 'football', 'team', 'in', 'ligue', 'num', 'the', 'second-highest', 'league', 'in', 'french', 'football', '</s>']
# 1.863853289569177e-78
# 2.7197478275022403e-81
# 3.672897172566378e-76
# The best matching document is document 3 with a probability of 3.672897172566378e-76
#
# Query: ['<s>', 'the', 'town', 'has', 'like', 'many', 'others', 'in', 'the', 'region', 'a', 'rich', 'and', 'interesting', 'history', '</s>']
# 8.532688270632883e-41
# 6.8848295738392306e-40
# 5.928808794507263e-39
# The best matching document is document 3 with a probability of 5.928808794507263e-39
#
# Query: ['<s>', 'this', 'is', 'exemplified', 'in', 'the', 'remains', 'of', 's', 'three', 'castles', 'razed', 'to', 'ground', 'level', 'by', 'the', 'order', 'of', 'richelieu', 'and', 'now', 'reduced', 'to', 'three', 'towers', '</s>']
# 1.222921322072729e-72
# 6.583234118329835e-70
# 4.814667987466174e-67
# The best matching document is document 3 with a probability of 4.814667987466174e-67
#
# Query: ['<s>', 'vincent', 'de', 'bourbon', 'great', 'grandson', 'of', 'louis', 'xiv', 'was', 'count', 'of', 'guingamp', 'from', 'num', 'till', 'his', 'death', 'in', 'num', '</s>']
# 1.1288334056106154e-56
# 3.2158437272470606e-60
# 6.147906106438583e-58
# The best matching document is document 1 with a probability of 1.1288334056106154e-56
#
# Query: ['<s>', 'lannion', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'of', 'brittany', 'in', 'north-western', 'france', '</s>']
# 3.090966326036762e-39
# 1.5490866541138264e-39
# 6.098203331493185e-39
# The best matching document is document 3 with a probability of 6.098203331493185e-39
#
# Query: ['<s>', 'it', 'is', 'a', 'sous-pr', 'fecture', 'of', 'tes-d', 'armor', 'the', 'capital', 'of', 'gor', 'and', 'the', 'center', 'of', 'an', 'urban', 'area', 'of', 'almost', 'inhabitants', '</s>']
# 2.9950188074886135e-58
# 3.6572294056055517e-60
# 3.32789851293662e-60
# The best matching document is document 1 with a probability of 2.9950188074886135e-58
#
# Query: ['<s>', 'inhabitants', 'of', 'lannion', 'are', 'called', 'lannionnais', '</s>']
# 1.7225932987781217e-18
# 4.37429393641631e-19
# 1.8562569175121788e-17
# The best matching document is document 3 with a probability of 1.8562569175121788e-17
#
# Query: ['<s>', 'lannion', 'takes', 'its', 'name', 'from', 'lann', 'huon', 'in', 'breton', 'or', 'land', 'of', 'huon', 'in', 'english', '</s>']
# 2.9078748528529447e-49
# 3.77212659280964e-42
# 1.0349971709934122e-44
# The best matching document is document 2 with a probability of 3.77212659280964e-42
#
# Query: ['<s>', 'most', 'of', 'the', 'area', 'indeed', 'use', 'to', 'belong', 'to', 'lord', 'huon', '</s>']
# 6.553104591846054e-36
# 1.2749256022922461e-30
# 1.4372245611663134e-31
# The best matching document is document 2 with a probability of 1.2749256022922461e-30
#
# Query: ['<s>', 'the', 'old', 'quarter', 'of', 'lannion', 'attracts', 'many', 'tourists', 'to', 'the', 'city', '</s>']
# 3.956436897327054e-33
# 1.6014563030424624e-31
# 4.790748537221046e-31
# The best matching document is document 3 with a probability of 4.790748537221046e-31
#
# Query: ['<s>', 'the', 'old', 'quarter', 'contains', 'old', 'squares', 'a', 'church', 'called', 'venez', 'half-timbered', 'houses', 'chapels', 'and', 'frescoes', '</s>']
# 2.4232290440441202e-49
# 2.884310520326506e-48
# 4.918520160864826e-46
# The best matching document is document 3 with a probability of 4.918520160864826e-46
#
# Query: ['<s>', 'on', 'num', 'october', 'num', 'the', 'municipality', 'launched', 'a', 'linguistic', 'plan', 'to', 'promote', 'breton', 'language', 'through', 'the', 'ya', 'brezhoneg', 'yes', 'to', 'breton', 'charter', '</s>']
# 1.152308657743248e-69
# 5.48855770301512e-69
# 2.12511773582274e-65
# The best matching document is document 3 with a probability of 2.12511773582274e-65
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 2.307483018351329e-29
# 2.2520479261534624e-32
# 1.960214609812945e-30
# The best matching document is document 1 with a probability of 2.307483018351329e-29
#
# Query: ['<s>', 'lannion', 'is', 'a', 'large', 'telecommunications', 'research', 'center', 'in', 'france', 'with', 'several', 'firms', 'such', 'as', 'alcatel-lucent', 'orange', 'france', 'telecom', 'and', 'sagem', 'operating', 'there', '</s>']
# 2.880771644358121e-72
# 3.2159517791104217e-71
# 3.510310257727441e-70
# The best matching document is document 3 with a probability of 3.510310257727441e-70
#
# Query: ['<s>', 'regular', 'concerts', 'are', 'held', 'in', 'the', 'town', 'square', 'during', 'the', 'summer', 'months', 'known', 'as', 'les', 'tardives', '</s>']
# 2.2082526580312842e-46
# 7.157020808744063e-48
# 2.3421524575546777e-47
# The best matching document is document 1 with a probability of 2.2082526580312842e-46
#
# Query: ['<s>', 'lannion', 'is', 'also', 'home', 'to', 'the', 'magique', 'a', 'well', 'known', 'theater', 'company', 'in', 'the', 'area', '</s>']
# 5.332930169145553e-43
# 1.1231369614745885e-42
# 1.270459027394414e-40
# The best matching document is document 3 with a probability of 1.270459027394414e-40
#
# Query: ['<s>', 'lannion', 'is', 'served', 'by', 'extensive', 'transport', 'links', '</s>']
# 5.944076255273022e-23
# 5.946565982077636e-23
# 5.475358568778842e-23
# The best matching document is document 2 with a probability of 5.946565982077636e-23
#
# Query: ['<s>', 'the', 'nearby', 'airport', 'lannion', 'te', 'de', 'granit', 'airport', 'was', 'recently', 'expanded', 'to', 'accommodate', 'larger', 'flights', 'arriving', 'from', 'paris', 'and', 'other', 'french', 'destinations', '</s>']
# 7.903046660533485e-75
# 3.2316905316998685e-71
# 4.387887822159299e-70
# The best matching document is document 3 with a probability of 4.387887822159299e-70
#
# Query: ['<s>', 'the', 'station', 'provides', 'tgv', 'services', 'to', 'brest', 'brieuc', 'rennes', 'and', 'paris', 'as', 'well', 'as', 'ter', 'links', 'to', 'local', 'stations', '</s>']
# 7.374775409556785e-66
# 4.0456623731716105e-59
# 3.825363799561784e-56
# The best matching document is document 3 with a probability of 3.825363799561784e-56
#
# Query: ['<s>', 'saint-brieuc', 'breton', 'sant-brieg', 'gallo', 'saent-berioec', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'brittany', 'in', 'north-western', 'france', '</s>']
# 1.8931476906594692e-54
# 1.3391951587672664e-54
# 4.663300631846748e-54
# The best matching document is document 3 with a probability of 4.663300631846748e-54
#
# Query: ['<s>', 'it', 'has', 'a', 'cathedral', '</s>']
# 1.3395402269288311e-11
# 1.1166507749097213e-10
# 1.5840059029437262e-13
# The best matching document is document 2 with a probability of 1.1166507749097213e-10
#
# Query: ['<s>', 'saint-brieuc', 'is', 'named', 'after', 'a', 'welsh', 'monk', 'brioc', 'who', 'evangelized', 'the', 'region', 'in', 'the', 'num', 'century', 'and', 'established', 'an', 'oratory', 'there', '</s>']
# 2.028757989724622e-62
# 8.188218667238886e-62
# 3.24623540356567e-61
# The best matching document is document 3 with a probability of 3.24623540356567e-61
#
# Query: ['<s>', 'bro', 'de', 'saint-brieuc', 'one', 'of', 'the', 'nine', 'traditional', 'bishoprics', 'of', 'brittany', 'which', 'were', 'used', 'as', 'administrative', 'areas', 'before', 'the', 'french', 'revolution', 'was', 'named', 'after', 'saint-brieuc', '</s>']
# 1.0127712812196513e-74
# 1.3715071079853822e-71
# 5.3859184607898036e-76
# The best matching document is document 2 with a probability of 1.3715071079853822e-71
#
# Query: ['<s>', 'saint-brieuc', 'is', 'one', 'of', 'the', 'towns', 'in', 'europe', 'that', 'hosts', 'the', 'iu', 'honors', 'program', '</s>']
# 1.5454831630183812e-38
# 1.6523590977214148e-38
# 1.0163672219155308e-38
# The best matching document is document 2 with a probability of 1.6523590977214148e-38
#
# Query: ['<s>', 'the', 'cemetery', 'of', 'saint', 'michel', 'contains', 'graves', 'of', 'several', 'notable', 'bretons', 'and', 'sculptures', 'by', 'paul', 'le', 'goff', 'and', 'jean', 'boucher', '</s>']
# 1.4607057526017278e-60
# 3.71237371110772e-62
# 9.996553829310167e-61
# The best matching document is document 1 with a probability of 1.4607057526017278e-60
#
# Query: ['<s>', 'outside', 'the', 'wall', 'is', 'armel', 'beaufils', 'statue', 'of', 'anatole', 'le', 'braz', '</s>']
# 3.9564368973270544e-34
# 3.143151899833543e-34
# 5.203800176207518e-34
# The best matching document is document 3 with a probability of 5.203800176207518e-34
#
# Query: ['<s>', 'le', 'goff', 'who', 'was', 'killed', 'with', 'his', 'two', 'brothers', 'in', 'world', 'war', 'i', 'is', 'also', 'commemorated', 'in', 'a', 'street', 'and', 'with', 'his', 'major', 'sculptural', 'work', 'la', 'forme', 'se', 'gageant', 'de', 'la', 're', 'in', 'the', 'central', 'gardens', 'which', 'also', 'includes', 'a', 'memorial', 'to', 'him', 'by', 'jules-charles', 'le', 'bozec', 'and', 'work', 'by', 'francis', 'renaud', '</s>']
# 5.42804544537163e-161
# 6.104295593937427e-163
# 5.956592180431061e-160
# The best matching document is document 3 with a probability of 5.956592180431061e-160
#
# Query: ['<s>', 'the', 'town', 'of', 'brieux', 'in', 'saskatchewan', 'canada', 'is', 'named', 'after', 'saint-brieuc', 'of', 'brittany', '</s>']
# 7.4183191824882286e-37
# 4.8382233178572324e-34
# 7.317843997791822e-37
# The best matching document is document 2 with a probability of 4.8382233178572324e-34
#
# Query: ['<s>', 'it', 'was', 'founded', 'by', 'immigrants', 'from', 'this', 'region', 'in', 'brittany', '</s>']
# 1.5383220122342192e-29
# 4.666339467348262e-27
# 4.356032466250988e-31
# The best matching document is document 2 with a probability of 4.666339467348262e-27
#
# Query: ['<s>', 'it', 'was', 'settled', 'in', 'the', 'early', 'num', '</s>']
# 4.186063209152598e-15
# 2.894456058584663e-18
# 1.0312538430623219e-18
# The best matching document is document 1 with a probability of 4.186063209152598e-15
#
# Query: ['<s>', 'the', 'town', 'is', 'located', 'by', 'the', 'english', 'channel', 'in', 'the', 'bay', 'of', 'saint-brieuc', '</s>']
# 4.506802770217438e-32
# 1.0321543078095431e-32
# 3.0628353278327264e-32
# The best matching document is document 1 with a probability of 4.506802770217438e-32
#
# Query: ['<s>', 'two', 'rivers', 'flow', 'through', 'saint-brieuc', 'the', 't', 'and', 'the', 'dic', '</s>']
# 6.369863404696559e-30
# 2.0552022555711596e-30
# 9.936367336458465e-30
# The best matching document is document 3 with a probability of 9.936367336458465e-30
#
# Query: ['<s>', 'other', 'towns', 'of', 'notable', 'size', 'in', 'the', 'partement', 'of', 'tes', 'are', 'dinan', 'and', 'all', 'sous-pr', 'fectures', '</s>']
# 7.949709568912624e-46
# 1.0113816110235803e-48
# 3.320001108583757e-46
# The best matching document is document 1 with a probability of 7.949709568912624e-46
#
# Query: ['<s>', 'in', 'num', 'large', 'amounts', 'of', 'sea', 'lettuce', 'a', 'type', 'of', 'algae', 'washed', 'up', 'on', 'many', 'beaches', 'of', 'brittany', 'and', 'when', 'it', 'rotted', 'it', 'emitted', 'dangerous', 'levels', 'of', 'hydrogen', 'sulphide', '</s>']
# 9.435757278443962e-83
# 5.002072835092433e-87
# 3.7110870954855145e-87
# The best matching document is document 1 with a probability of 9.435757278443962e-83
#
# Query: ['<s>', 'a', 'horse', 'and', 'some', 'dogs', 'died', 'and', 'a', 'council', 'worker', 'driving', 'a', 'truckload', 'of', 'it', 'fell', 'unconscious', 'at', 'the', 'wheel', 'and', 'died', '</s>']
# 9.186469772221807e-63
# 4.232904404636058e-63
# 2.5164664681156513e-62
# The best matching document is document 3 with a probability of 2.5164664681156513e-62
#
# Query: ['<s>', 'the', 'beach', 'at', 'saint-brieuc', 'suffered', 'bad', 'damage', 'and', 'had', 'to', 'be', 'shut', '</s>']
# 4.52250144364807e-40
# 2.1364545268036592e-38
# 1.1644180472412264e-34
# The best matching document is document 3 with a probability of 1.1644180472412264e-34
#
# Query: ['<s>', 'langueux', 'la', 'augon', 'rin', 'ploufragan', 'gueux', 'and', 'muson', '</s>']
# 4.076712579005798e-28
# 1.9039522145752194e-28
# 6.3592750953334175e-28
# The best matching document is document 3 with a probability of 6.3592750953334175e-28
#
# Query: ['<s>', 'inhabitants', 'of', 'saint-brieuc', 'are', 'called', 'briochins', 'or', 'briochains', '</s>']
# 7.383945658724251e-26
# 2.3168438891211578e-24
# 4.7257049834831444e-23
# The best matching document is document 3 with a probability of 4.7257049834831444e-23
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'the', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 2.8843537729391613e-30
# 2.3397900531464548e-33
# 2.450268262266181e-31
# The best matching document is document 1 with a probability of 2.8843537729391613e-30
#
# Query: ['<s>', 'the', 'gare', 'de', 'saint-brieuc', 'railway', 'station', 'is', 'connected', 'by', 'tgv', 'atlantique', 'to', 'paris', 'montparnasse', 'station', '</s>']
# 1.2116145220220601e-49
# 1.1537242081306025e-47
# 5.621165898131228e-46
# The best matching document is document 3 with a probability of 5.621165898131228e-46
#
# Query: ['<s>', 'an', 'air', 'service', 'from', 'saint-brieuc', 'armor', 'airport', 'to', 'newquay', 'in', 'cornwall', 'is', 'operated', 'by', 'isles', 'of', 'scilly', 'skybus', 'four', 'days', 'per', 'week', '</s>']
# 1.0435595281687291e-69
# 5.788713202398757e-70
# 4.513256045649568e-70
# The best matching document is document 1 with a probability of 1.0435595281687291e-69
#
# Query: ['<s>', 'bourseul', 'gallo', 'rsoeut', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'bretagne', 'in', 'north-western', 'france', '</s>']
# 4.41650531606257e-47
# 3.2206593639348284e-47
# 1.1242331796262457e-46
# The best matching document is document 3 with a probability of 1.1242331796262457e-46
#
# Query: ['<s>', 'inhabitants', 'of', 'bourseul', 'are', 'called', 'bourseulais', '</s>']
# 1.7225932987781217e-18
# 4.37429393641631e-19
# 1.8562569175121788e-17
# The best matching document is document 3 with a probability of 1.8562569175121788e-17
#
# Query: ['<s>', 'stoke', 'by', 'nayland', 'in', 'the', 'english', 'county', 'of', 'suffolk', 'lies', 'close', 'to', 'the', 'border', 'with', 'essex', 'in', 'what', 'is', 'sometimes', 'referred', 'to', 'as', 'constable', 'country', '</s>']
# 3.375904270732171e-75
# 1.6458085295824585e-70
# 1.992297877333819e-69
# The best matching document is document 3 with a probability of 1.992297877333819e-69
#
# Query: ['<s>', 'it', 'contains', 'a', 'church', 'st', 'mary', 'part', 'of', 'the', 'deanery', 'of', 'hadleigh', 'in', 'the', 'diocese', 'of', 'chelmsford', '</s>']
# 3.5997278641732474e-44
# 6.393299451807617e-46
# 3.014858824773853e-43
# The best matching document is document 3 with a probability of 3.014858824773853e-43
#
# Query: ['<s>', 'the', 'incumbent', 'is', 'the', 'revd', '</s>']
# 8.372126418305192e-12
# 1.1658344142613732e-11
# 1.6203060382195198e-11
# The best matching document is document 3 with a probability of 1.6203060382195198e-11
#
# Query: ['<s>', 'v', 'armstrong', '</s>']
# 4.286528726172258e-08
# 4.158139708171776e-08
# 4.1479834578419707e-08
# The best matching document is document 1 with a probability of 4.286528726172258e-08
#
# Query: ['<s>', 'the', 'village', 'located', 'within', 'babergh', 'district', 'contains', 'many', 'cottages', 'and', 'timber', 'framed', 'houses', 'and', 'all', 'surround', 'a', 'large', 'recreation', 'field', 'which', 'makes', 'up', 'the', 'center', 'of', 'the', 'village', '</s>']
# 4.962397929881328e-87
# 9.603425871988026e-87
# 2.280613194482181e-83
# The best matching document is document 3 with a probability of 2.280613194482181e-83
#
# Query: ['<s>', 'the', 'population', 'of', 'the', 'stoke-by-nayland', 'civil', 'parish', 'at', 'the', 'num', 'census', 'was', 'num', 'comprising', 'num', 'males', 'and', 'num', 'females', '</s>']
# 3.999697626859165e-46
# 1.5535343512978995e-56
# 8.481229011307618e-49
# The best matching document is document 1 with a probability of 3.999697626859165e-46
#
# Query: ['<s>', 'two', 'schools', 'a', 'primary', 'and', 'a', 'middle', 'school', 'are', 'in', 'the', 'village', 'as', 'are', 'two', 'public', 'houses', 'the', 'angel', 'inn', 'and', 'the', 'crown', '</s>']
# 9.56923934606438e-64
# 8.673776686128347e-67
# 8.171858702677153e-62
# The best matching document is document 3 with a probability of 8.171858702677153e-62
#
# Query: ['<s>', 'stoke', 'by', 'nayland', 'is', 'about', 'miles', 'from', 'nayland', 'and', 'stands', 'on', 'a', 'ridge', 'overlooking', 'the', 'stour', 'and', 'box', 'valleys', '</s>']
# 2.3664346133243353e-56
# 1.2307514961478754e-55
# 2.231462216411041e-56
# The best matching document is document 2 with a probability of 1.2307514961478754e-55
#
# Query: ['<s>', 'immediately', 'to', 'the', 'north', 'of', 'the', 'village', 'lies', 'the', 'hamlet', 'of', 'scotland', 'street', '</s>']
# 3.709159591244113e-35
# 6.482535212180654e-34
# 3.368495065233547e-33
# The best matching document is document 3 with a probability of 3.368495065233547e-33
#
# Query: ['<s>', 'st', 'mary', 'church', 'was', 'rebuilt', 'in', 'the', 'fifteenth', 'century', 'and', 'renovated', 'in', 'num', '</s>']
# 3.98116462793535e-35
# 3.975989078892152e-38
# 3.6551961881114854e-33
# The best matching document is document 3 with a probability of 3.6551961881114854e-33
#
# Query: ['<s>', 'the', 'church', 'is', 'on', 'the', 'site', 'of', 'a', 'num', 'century', 'minster', '</s>']
# 3.4828571808240366e-27
# 3.247914365527883e-28
# 8.497269825037442e-25
# The best matching document is document 3 with a probability of 8.497269825037442e-25
#
# Query: ['<s>', 'a', 'saxon', 'monastery', 'was', 'founded', 'here', 'during', 'the', 'time', 'of', 'king', 'edmund', 'by', 'earl', 'alfgar', 'who', 'died', 'in', 'num', '</s>']
# 6.249527541967446e-50
# 1.820548067927225e-58
# 1.2577591242755602e-55
# The best matching document is document 1 with a probability of 6.249527541967446e-50
#
# Query: ['<s>', 'the', 'num', 'national', 'gazetteer', 'of', 'great', 'britain', 'describes', 'the', 'village', 'such', '</s>']
# 9.554795107044838e-31
# 1.2572607599334174e-33
# 7.984580895368411e-32
# The best matching document is document 1 with a probability of 9.554795107044838e-31
#
# Query: ['<s>', 'stoke-by-nayland', 'a', 'parish', 'in', 'the', 'hundred', 'of', 'babergh', 'county', 'suffolk', 'num', 'mile', 'of', 'nayland', 'and', 'num', 'miles', 'of', 'bures', 'railway', 'station', '</s>']
# 6.38937345597571e-57
# 4.3391381038921386e-63
# 9.07776761028822e-59
# The best matching document is document 1 with a probability of 6.38937345597571e-57
#
# Query: ['<s>', 'colchester', 'is', 'its', 'post', 'town', '</s>']
# 2.2967910650374956e-17
# 1.4301024976123721e-15
# 1.3200049191197719e-15
# The best matching document is document 2 with a probability of 1.4301024976123721e-15
#
# Query: ['<s>', 'the', 'village', 'which', 'was', 'formerly', 'a', 'market', 'town', 'is', 'situated', 'near', 'the', 'river', 'stour', '</s>']
# 4.2663441353164414e-41
# 1.8359545530237944e-39
# 1.693945369859218e-39
# The best matching document is document 2 with a probability of 1.8359545530237944e-39
#
# Query: ['<s>', 'the', 'parish', 'contains', 'the', 'chapelry', 'of', 'leavenheath', 'and', 'had', 'a', 'monastery', 'endowed', 'by', 'the', 'saxon', 'earl', 'of', 'algar', 'traces', 'of', 'which', 'are', 'still', 'existing', '</s>']
# 1.069852846143843e-65
# 1.0138180542227938e-67
# 4.432503715961047e-63
# The best matching document is document 3 with a probability of 4.432503715961047e-63
#
# Query: ['<s>', 'the', 'living', 'is', 'a', 'vicarage', 'in', 'the', 'diocese', 'of', 'ely', 'value', 'num', '</s>']
# 8.707142952060094e-29
# 1.9868970425333703e-31
# 2.2557782189488028e-29
# The best matching document is document 1 with a probability of 8.707142952060094e-29
#
# Query: ['<s>', 'the', 'church', 'dedicated', 'to', 'mary', 'is', 'an', 'ancient', 'structure', 'with', 'a', 'tower', 'and', 'six', 'bells', '</s>']
# 8.833010632125139e-46
# 4.679737339477452e-44
# 1.1116516489701119e-41
# The best matching document is document 3 with a probability of 1.1116516489701119e-41
#
# Query: ['<s>', 'there', 'is', 'also', 'a', 'district', 'church', 'at', 'leavenheath', 'the', 'living', 'of', 'which', 'is', 'a', 'perpetual', 'curacy', 'value', 'num', '</s>']
# 2.0702368669043292e-50
# 7.581429216270911e-53
# 1.3957679744323397e-47
# The best matching document is document 3 with a probability of 1.3957679744323397e-47
#
# Query: ['<s>', 'the', 'parochial', 'charities', 'produce', 'about', 'num', 'per', 'annum', 'exclusive', 'of', 'some', 'almshouses', '</s>']
# 3.956436897327055e-35
# 1.6023408951027444e-38
# 2.649592757743136e-38
# The best matching document is document 1 with a probability of 3.956436897327055e-35
#
# Query: ['<s>', 'num', 'go', 'towards', 'lady', 'windsor', 'hospital', '</s>']
# 1.902104401687367e-20
# 7.189475878413194e-23
# 2.1901434275115366e-21
# The best matching document is document 1 with a probability of 1.902104401687367e-20
#
# Query: ['<s>', 'there', 'is', 'a', 'national', 'school', 'for', 'both', 'sexes', '</s>']
# 1.2306576097873754e-26
# 7.722812963737192e-25
# 1.0266297316460328e-24
# The best matching document is document 3 with a probability of 1.0266297316460328e-24
#
# Query: ['<s>', 'tendring', 'hall', 'is', 'the', 'principal', 'residence', '</s>']
# 2.8709888312968696e-18
# 4.665913532177396e-18
# 5.376802114540822e-18
# The best matching document is document 3 with a probability of 5.376802114540822e-18
#
# Query: ['<s>', 'the', 'birthstone', 'of', 'april', 'is', 'the', 'diamond', 'and', 'the', 'birth', 'flower', 'is', 'typically', 'listed', 'as', 'either', 'the', 'daisy', 'or', 'the', 'sweet', 'pea', '</s>']
# 1.3865827812447281e-57
# 1.1252210907522551e-54
# 1.2506970861801786e-38
# The best matching document is document 3 with a probability of 1.2506970861801786e-38

# %%
# no smoothing
doc1_model_nosmooth = UnigramLanguageModel(doc1_dataset, mode=DOC_MODE)
doc2_model_nosmooth = UnigramLanguageModel(doc2_dataset, mode=DOC_MODE)
doc3_model_nosmooth = UnigramLanguageModel(doc3_dataset, mode=DOC_MODE)
models_nosmooth = [doc1_model_nosmooth, doc2_model_nosmooth, doc3_model_nosmooth]
collection_nosmooth = UnigramLanguageModel(actual_dataset, mode=COL_MODE)

for query in actual_dataset_test:
    print('Query:', query)
    best_doc = None
    current_score = -np.inf
    for model in models_nosmooth:
        new_score = calculate_interpolated_sentence_probability(query, model, collection_nosmooth)
        print(new_score)
        if new_score > current_score:
            current_score = new_score
            best_doc = models_nosmooth.index(model)
    print('The best matching document is document', best_doc+1, 'with a probability of', current_score, '\n')
# Out:
# Query: ['<s>', 'the', 'website', 'and', 'monthly', 'newsletter', 'is', 'run', 'by', 'a', 'sub-committee', 'that', 'is', 'independent', 'to', 'the', 'parish', 'council', 'and', 'is', 'financed', 'through', 'selling', 'advertisement', 'space', 'to', 'local', 'businesses', '</s>']
# 9.921584418895225e-50
# 4.937726617351616e-53
# 2.851629716983247e-52
# The best matching document is document 1 with a probability of 9.921584418895225e-50
#
# Query: ['<s>', 'uk', 'was', 'designed', 'and', 'built', 'by', 'chris', 'chambers', 'the', 'site', 'is', 'designed', 'in', 'a', 'way', 'that', 'when', 'content', 'is', 'added', 'to', 'the', 'site', 'no', 'previous', 'content', 'needs', 'to', 'be', 'edited', 'therefore', 'creating', 'a', 'archive', 'over', 'time', 'meaning', 'that', 'every', 'single', 'article', 'that', 'is', 'added', 'is', 'stored', 'and', 'never', 'deleted', 'allowing', 'users', 'to', 'search', 'and', 'read', 'articles', 'going', 'far', 'back', 'as', 'the', 'website', 'launch', 'date', '</s>']
# 4.3722565294214055e-118
# 9.4574955318852e-129
# 5.5151452950961316e-129
# The best matching document is document 1 with a probability of 4.3722565294214055e-118
#
# Query: ['<s>', 'chelmondiston', 'is', 'a', 'small', 'village', 'and', 'civil', 'parish', 'in', 'suffolk', 'england', 'on', 'the', 'south', 'bank', 'of', 'the', 'river', 'orwell', 'and', 'num', 'miles', 'south-east', 'of', 'ipswich', '</s>']
# 1.898185228258354e-43
# 1.235072015758591e-49
# 4.132011459908727e-48
# The best matching document is document 1 with a probability of 1.898185228258354e-43
#
# Query: ['<s>', 'formerly', 'known', 'as', 'chelmington', 'and', 'was', 'in', 'the', 'old', 'hundreds', 'of', 'suffolk', 'of', 'babergh', '</s>']
# 4.4466574856129706e-24
# 2.3481619991220257e-27
# 9.095973522705064e-27
# The best matching document is document 1 with a probability of 4.4466574856129706e-24
#
# Query: ['<s>', 'the', 'former', 'church', 'site', 'has', 'not', 'been', 'a', 'very', 'lucky', 'one', '</s>']
# 7.905168863315798e-21
# 1.9852100780615043e-23
# 2.4335796082005588e-23
# The best matching document is document 1 with a probability of 7.905168863315798e-21
#
# Query: ['<s>', 'one', 'night', 'in', 'late', 'num', 'a', 'v2', 'rocket', 'hit', 'hakewill', 'church', 'build', 'work', 'and', 'the', 'little', 'church', 'was', 'almost', 'completely', 'destroyed', '</s>']
# 2.1867093829536245e-38
# 5.991170905034781e-44
# 6.007230487887058e-44
# The best matching document is document 1 with a probability of 2.1867093829536245e-38
#
# Query: ['<s>', 'it', 'was', 'not', 'until', 'num', 'that', 'basil', 'hatcher', 'was', 'given', 'the', 'commission', 'to', 'provide', 'a', 'replacement', 'st', 'andrew', 'church', '</s>']
# 1.434700026155873e-34
# 1.5553415824446582e-38
# 6.715141301174948e-40
# The best matching document is document 1 with a probability of 1.434700026155873e-34
#
# Query: ['<s>', 'the', 'church', 'includes', 'a', 'fine', 'set', 'of', 'stained', 'glass', 'windows', 'the', 'num', 'work', 'of', 'francis', 'skeat', '</s>']
# 3.388704073779125e-27
# 1.2864160238028563e-31
# 3.736412062234559e-31
# The best matching document is document 1 with a probability of 3.388704073779125e-27
#
# Query: ['<s>', 'there', 'is', 'a', 'newer', 'methodist', 'church', 'on', 'the', 'main', 'road', 'and', 'a', 'baptist', 'on', 'pin', 'mill', 'road', '</s>']
# 5.738800104623491e-32
# 2.3354425948895576e-35
# 1.2108742794278662e-34
# The best matching document is document 1 with a probability of 5.738800104623491e-32
#
# Query: ['<s>', 'pubs', 'in', 'the', 'area', 'include', 'the', 'butt', 'and', 'oyster', 'and', 'the', 'red', 'lion', '</s>']
# 1.0004979342629184e-21
# 1.2857491479637033e-24
# 2.4998059278716954e-23
# The best matching document is document 1 with a probability of 1.0004979342629184e-21
#
# Query: ['<s>', 'dinan', 'gallo', 'dinan', 'is', 'a', 'walled', 'breton', 'town', 'and', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'north-western', 'france', '</s>']
# 3.5867500653896823e-35
# 8.748796401251203e-39
# 7.427820353662586e-38
# The best matching document is document 1 with a probability of 3.5867500653896823e-35
#
# Query: ['<s>', 'its', 'geographical', 'setting', 'is', 'exceptional', '</s>']
# 2.1778662957448034e-10
# 3.396915955476472e-11
# 2.808043053538621e-11
# The best matching document is document 1 with a probability of 2.1778662957448034e-10
#
# Query: ['<s>', 'instead', 'of', 'nestling', 'on', 'the', 'valley', 'floor', 'like', 'morlaix', 'most', 'urban', 'development', 'has', 'been', 'on', 'the', 'hillside', 'overlooking', 'the', 'river', 'rance', '</s>']
# 3.950092310596056e-37
# 1.9547652900435595e-42
# 2.542644967785226e-42
# The best matching document is document 1 with a probability of 3.950092310596056e-37
#
# Query: ['<s>', 'the', 'area', 'alongside', 'the', 'river', 'rance', 'is', 'known', 'as', 'the', 'port', 'of', 'dinan', 'and', 'is', 'connected', 'to', 'the', 'town', 'by', 'the', 'steep', 'streets', 'rue', 'jerzual', 'and', 'its', 'continuation', 'outside', 'the', 'walls', 'the', 'rue', 'de', 'petit', 'fort', 'this', 'river', 'has', 'moderate', 'turbidity', 'and', 'its', 'brownish', 'water', 'is', 'somewhat', 'low', 'in', 'velocity', 'due', 'to', 'the', 'slight', 'gradient', 'of', 'the', 'watercourse', 'ph', 'levels', 'have', 'been', 'measured', 'at', 'within', 'the', 'city', 'of', 'dinan', 'and', 'electrical', 'conductivity', 'of', 'the', 'waters', 'have', 'tested', 'at', 'num', 'micro-siemens', 'per', 'centimetre', '</s>']
# 5.419765345352612e-141
# 2.5543434616427386e-159
# 6.085696765584423e-156
# The best matching document is document 1 with a probability of 5.419765345352612e-141
#
# Query: ['<s>', 'in', 'the', 'center', 'of', 'dinan', 'the', 'rance', 'summer', 'flows', 'are', 'typically', 'in', 'the', 'range', 'of', 'num', 'cubic', 'feet', 'per', 'second', '</s>']
# 3.3092813220499274e-33
# 1.6255828152002235e-38
# 6.043627171057451e-38
# The best matching document is document 1 with a probability of 3.3092813220499274e-33
#
# Query: ['<s>', 'for', 'many', 'years', 'the', 'bridge', 'over', 'the', 'river', 'rance', 'at', 'dinan', 'was', 'the', 'most', 'northerly', 'crossing', 'point', 'on', 'the', 'river', 'but', 'the', 'tidal', 'power', 'station', 'at', 'the', 'mouth', 'of', 'the', 'estuary', 'constructed', 'in', 'the', 'num', 'downstream', 'from', 'dinan', 'incorporates', 'a', 'num', 'meter', 'long', 'tidal', 'barrage', 'which', 'doubles', 'as', 'a', 'crossing', 'point', 'nearer', 'to', 'the', 'sea', '</s>']
# 3.793472670660139e-94
# 6.897488553177617e-107
# 1.4517767674570534e-106
# The best matching document is document 1 with a probability of 3.793472670660139e-94
#
# Query: ['<s>', 'the', 'medieval', 'town', 'on', 'the', 'hilltop', 'has', 'many', 'fine', 'old', 'buildings', 'some', 'as', 'early', 'as', 'num', 'century', '</s>']
# 1.1195952040722554e-30
# 1.1677212974447864e-35
# 3.79644151409422e-35
# The best matching document is document 1 with a probability of 1.1195952040722554e-30
#
# Query: ['<s>', 'the', 'town', 'retains', 'a', 'large', 'section', 'of', 'the', 'city', 'walls', 'part', 'of', 'which', 'can', 'be', 'walked', 'around', '</s>']
# 1.0329840188322281e-29
# 8.353350803914648e-34
# 4.641505667372121e-33
# The best matching document is document 1 with a probability of 1.0329840188322281e-29
#
# Query: ['<s>', 'major', 'historical', 'attractions', 'include', 'the', 'jacobins', 'theatre', 'dating', 'from', 'num', 'the', 'flamboyant', 'gothic', 'st', 'malo', 'church', 'the', 'romanesque', 'st', 'saviour', 'basilica', 'duchess', 'anne', 'tower', 'and', 'the', 'cents', 'teau', 'de', 'dinan', '</s>']
# 3.5972521045553534e-53
# 5.978708279328709e-61
# 2.2177676120774065e-60
# The best matching document is document 1 with a probability of 3.5972521045553534e-53
#
# Query: ['<s>', 'a', 'major', 'highlight', 'in', 'the', 'calendar', 'is', 'dinan', 'te', 'des', 'remparts', '</s>']
# 4.862419960517783e-20
# 2.38225209321147e-22
# 3.9180631685825924e-22
# The best matching document is document 1 with a probability of 4.862419960517783e-20
#
# Query: ['<s>', 'the', 'town', 'is', 'transformed', 'with', 'decoration', 'and', 'many', 'locals', 'dress', 'up', 'in', 'medieval', 'garb', 'for', 'this', 'two-day', 'festival', '</s>']
# 1.4169876801539488e-33
# 1.130052868494947e-37
# 3.321886324832437e-37
# The best matching document is document 1 with a probability of 1.4169876801539488e-33
#
# Query: ['<s>', 'it', 'occurs', 'only', 'every', 'other', 'year', '</s>']
# 1.6333996787583124e-11
# 5.44355381360824e-14
# 4.3332374673993107e-14
# The best matching document is document 1 with a probability of 1.6333996787583124e-11
#
# Query: ['<s>', 'inhabitants', 'of', 'dinan', 'are', 'called', 'dinannais', '</s>']
# 1.633399673186483e-11
# 3.2873374206526316e-13
# 3.9488096571938723e-13
# The best matching document is document 1 with a probability of 1.633399673186483e-11
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 7.779871936828522e-19
# 5.360067209795459e-22
# 1.1827653190228342e-21
# The best matching document is document 1 with a probability of 7.779871936828522e-19
#
# Query: ['<s>', 'dinan', 'was', 'also', 'a', 'favorite', 'place', 'for', 'artists', 'to', 'visit', 'in', 'search', 'of', 'picturesque', 'views', '</s>']
# 4.518272098372169e-28
# 6.271539158251546e-31
# 4.010415613465095e-31
# The best matching document is document 1 with a probability of 4.518272098372169e-28
#
# Query: ['<s>', 'the', 'british', 'artist', 'john', 'everett', 'millais', 'lived', 'there', 'as', 'a', 'child', '</s>']
# 7.807574185987113e-21
# 1.972402270724028e-23
# 4.867159215631094e-23
# The best matching document is document 1 with a probability of 7.807574185987113e-21
#
# Query: ['<s>', 'it', 'was', 'also', 'painted', 'by', 'edward', 'ward', 'and', 'horace', 'tuck', 'among', 'others', '</s>']
# 8.00398347410335e-23
# 3.2019517381874704e-26
# 1.7634634839241406e-26
# The best matching document is document 1 with a probability of 8.00398347410335e-23
#
# Query: ['<s>', 'guingamp', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'brittany', 'in', 'north-western', 'france', '</s>']
# 1.2351826348924915e-25
# 5.832531417173935e-28
# 1.520987254884539e-27
# The best matching document is document 1 with a probability of 1.2351826348924915e-25
#
# Query: ['<s>', 'inhabitants', 'of', 'guingamp', 'are', 'called', 'guingampais', '</s>']
# 1.633399673186483e-11
# 3.2873374206526316e-13
# 3.9488096571938723e-13
# The best matching document is document 1 with a probability of 1.633399673186483e-11
#
# Query: ['<s>', 'the', 'municipality', 'launched', 'a', 'linguistic', 'plan', 'through', 'ya', 'brezhoneg', 'on', 'num', 'july', 'num', '</s>']
# 1.9518935464967766e-23
# 8.20979092912991e-28
# 9.506170343028377e-28
# The best matching document is document 1 with a probability of 1.9518935464967766e-23
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'the', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 9.724839921035615e-20
# 5.568900997166744e-23
# 1.4784566487747376e-22
# The best matching document is document 1 with a probability of 9.724839921035615e-20
#
# Query: ['<s>', 'the', 'breton', 'dance', 'festival', 'of', 'saint-loup', 'is', 'held', 'every', 'year', 'in', 'mid-august', '</s>']
# 3.6017925633465054e-21
# 4.640750830931405e-24
# 7.346368441092333e-24
# The best matching document is document 1 with a probability of 3.6017925633465054e-21
#
# Query: ['<s>', 'then', 'there', 'is', 'the', 'annual', 'which', 'brings', 'pilgrims', 'to', 'pay', 'homage', 'to', 'the', 'black', 'in', 'the', 'basilica', 'of', 'notre', 'dame', 'de', 'bon', 'secours', '</s>']
# 1.2344038470612674e-40
# 1.572329014195071e-44
# 1.151341424475248e-43
# The best matching document is document 1 with a probability of 1.2344038470612674e-40
#
# Query: ['<s>', 'guingamp', 'is', 'home', 'to', 'the', 'num', 'coupe', 'de', 'france', 'holders', 'en', 'avant', 'de', 'guingamp', 'a', 'football', 'team', 'in', 'ligue', 'num', 'the', 'second-highest', 'league', 'in', 'french', 'football', '</s>']
# 1.2699628056185882e-46
# 6.512480041872405e-53
# 1.5422681530141366e-52
# The best matching document is document 1 with a probability of 1.2699628056185882e-46
#
# Query: ['<s>', 'the', 'town', 'has', 'like', 'many', 'others', 'in', 'the', 'region', 'a', 'rich', 'and', 'interesting', 'history', '</s>']
# 6.099667332802433e-25
# 5.184472370828723e-28
# 3.327159620060672e-27
# The best matching document is document 1 with a probability of 6.099667332802433e-25
#
# Query: ['<s>', 'this', 'is', 'exemplified', 'in', 'the', 'remains', 'of', 's', 'three', 'castles', 'razed', 'to', 'ground', 'level', 'by', 'the', 'order', 'of', 'richelieu', 'and', 'now', 'reduced', 'to', 'three', 'towers', '</s>']
# 2.3434385534053753e-44
# 4.972367855651471e-49
# 7.127719768342552e-48
# The best matching document is document 1 with a probability of 2.3434385534053753e-44
#
# Query: ['<s>', 'vincent', 'de', 'bourbon', 'great', 'grandson', 'of', 'louis', 'xiv', 'was', 'count', 'of', 'guingamp', 'from', 'num', 'till', 'his', 'death', 'in', 'num', '</s>']
# 1.0202311297108431e-33
# 2.428951741764648e-39
# 2.9843921063822904e-40
# The best matching document is document 1 with a probability of 1.0202311297108431e-33
#
# Query: ['<s>', 'lannion', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'of', 'brittany', 'in', 'north-western', 'france', '</s>']
# 3.705547904677476e-25
# 1.166506283434787e-27
# 3.4222213234902126e-27
# The best matching document is document 1 with a probability of 3.705547904677476e-25
#
# Query: ['<s>', 'it', 'is', 'a', 'sous-pr', 'fecture', 'of', 'tes-d', 'armor', 'the', 'capital', 'of', 'gor', 'and', 'the', 'center', 'of', 'an', 'urban', 'area', 'of', 'almost', 'inhabitants', '</s>']
# 4.539480551508817e-37
# 2.7595522816098134e-42
# 4.926679903878374e-41
# The best matching document is document 1 with a probability of 4.539480551508817e-37
#
# Query: ['<s>', 'inhabitants', 'of', 'lannion', 'are', 'called', 'lannionnais', '</s>']
# 1.633399673186483e-11
# 3.2873374206526316e-13
# 3.9488096571938723e-13
# The best matching document is document 1 with a probability of 1.633399673186483e-11
#
# Query: ['<s>', 'lannion', 'takes', 'its', 'name', 'from', 'lann', 'huon', 'in', 'breton', 'or', 'land', 'of', 'huon', 'in', 'english', '</s>']
# 4.407398480350842e-28
# 2.840518547324969e-30
# 1.77133608876305e-31
# The best matching document is document 1 with a probability of 4.407398480350842e-28
#
# Query: ['<s>', 'most', 'of', 'the', 'area', 'indeed', 'use', 'to', 'belong', 'to', 'lord', 'huon', '</s>']
# 4.6845445115922894e-20
# 9.590885050594104e-22
# 2.6446926387934914e-21
# The best matching document is document 1 with a probability of 4.6845445115922894e-20
#
# Query: ['<s>', 'the', 'old', 'quarter', 'of', 'lannion', 'attracts', 'many', 'tourists', 'to', 'the', 'city', '</s>']
# 4.74310131798717e-19
# 3.811603349138616e-21
# 8.815642129311082e-21
# The best matching document is document 1 with a probability of 4.74310131798717e-19
#
# Query: ['<s>', 'the', 'old', 'quarter', 'contains', 'old', 'squares', 'a', 'church', 'called', 'venez', 'half-timbered', 'houses', 'chapels', 'and', 'frescoes', '</s>']
# 3.672832066959035e-28
# 6.878752349501381e-32
# 2.5671537518305065e-31
# The best matching document is document 1 with a probability of 3.672832066959035e-28
#
# Query: ['<s>', 'on', 'num', 'october', 'num', 'the', 'municipality', 'launched', 'a', 'linguistic', 'plan', 'to', 'promote', 'breton', 'language', 'through', 'the', 'ya', 'brezhoneg', 'yes', 'to', 'breton', 'charter', '</s>']
# 1.3166974368653522e-39
# 4.149728765392057e-45
# 9.594511870627069e-45
# The best matching document is document 1 with a probability of 1.3166974368653522e-39
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 7.779871936828522e-19
# 5.360067209795459e-22
# 1.1827653190228342e-21
# The best matching document is document 1 with a probability of 7.779871936828522e-19
#
# Query: ['<s>', 'lannion', 'is', 'a', 'large', 'telecommunications', 'research', 'center', 'in', 'france', 'with', 'several', 'firms', 'such', 'as', 'alcatel-lucent', 'orange', 'france', 'telecom', 'and', 'sagem', 'operating', 'there', '</s>']
# 3.291743592163381e-42
# 2.4314816984719085e-47
# 1.4739970827740448e-46
# The best matching document is document 1 with a probability of 3.291743592163381e-42
#
# Query: ['<s>', 'regular', 'concerts', 'are', 'held', 'in', 'the', 'town', 'square', 'during', 'the', 'summer', 'months', 'known', 'as', 'les', 'tardives', '</s>']
# 9.413066871608685e-29
# 5.394872394194876e-33
# 1.2224541675383366e-32
# The best matching document is document 1 with a probability of 9.413066871608685e-29
#
# Query: ['<s>', 'lannion', 'is', 'also', 'home', 'to', 'the', 'magique', 'a', 'well', 'known', 'theater', 'company', 'in', 'the', 'area', '</s>']
# 3.812292083001517e-27
# 2.6758567075206596e-29
# 7.129627757271277e-29
# The best matching document is document 1 with a probability of 3.812292083001517e-27
#
# Query: ['<s>', 'lannion', 'is', 'served', 'by', 'extensive', 'transport', 'links', '</s>']
# 3.3609046767102534e-14
# 1.4139085548874996e-15
# 1.0833078975271217e-15
# The best matching document is document 1 with a probability of 3.3609046767102534e-14
#
# Query: ['<s>', 'the', 'nearby', 'airport', 'lannion', 'te', 'de', 'granit', 'airport', 'was', 'recently', 'expanded', 'to', 'accommodate', 'larger', 'flights', 'arriving', 'from', 'paris', 'and', 'other', 'french', 'destinations', '</s>']
# 3.210967686304776e-41
# 7.730543103270682e-46
# 1.8424963534675548e-46
# The best matching document is document 1 with a probability of 3.210967686304776e-41
#
# Query: ['<s>', 'the', 'station', 'provides', 'tgv', 'services', 'to', 'brest', 'brieuc', 'rennes', 'and', 'paris', 'as', 'well', 'as', 'ter', 'links', 'to', 'local', 'stations', '</s>']
# 8.426863595938253e-36
# 9.658169503890216e-40
# 1.8569550884156469e-38
# The best matching document is document 1 with a probability of 8.426863595938253e-36
#
# Query: ['<s>', 'saint-brieuc', 'breton', 'sant-brieg', 'gallo', 'saent-berioec', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'brittany', 'in', 'north-western', 'france', '</s>']
# 2.8694000523117455e-33
# 1.0104859843445138e-36
# 2.263716679211456e-36
# The best matching document is document 1 with a probability of 2.8694000523117455e-33
#
# Query: ['<s>', 'it', 'has', 'a', 'cathedral', '</s>']
# 3.5726858914664704e-08
# 2.6541122946396185e-09
# 3.3740589501618887e-09
# The best matching document is document 1 with a probability of 3.5726858914664704e-08
#
# Query: ['<s>', 'saint-brieuc', 'is', 'named', 'after', 'a', 'welsh', 'monk', 'brioc', 'who', 'evangelized', 'the', 'region', 'in', 'the', 'num', 'century', 'and', 'established', 'an', 'oratory', 'there', '</s>']
# 1.093354691476812e-37
# 1.954765290043559e-42
# 4.805784390309647e-42
# The best matching document is document 1 with a probability of 1.093354691476812e-37
#
# Query: ['<s>', 'bro', 'de', 'saint-brieuc', 'one', 'of', 'the', 'nine', 'traditional', 'bishoprics', 'of', 'brittany', 'which', 'were', 'used', 'as', 'administrative', 'areas', 'before', 'the', 'french', 'revolution', 'was', 'named', 'after', 'saint-brieuc', '</s>']
# 1.1572536066199382e-44
# 1.0359099699273898e-50
# 6.897099814721605e-51
# The best matching document is document 1 with a probability of 1.1572536066199382e-44
#
# Query: ['<s>', 'saint-brieuc', 'is', 'one', 'of', 'the', 'towns', 'in', 'europe', 'that', 'hosts', 'the', 'iu', 'honors', 'program', '</s>']
# 1.852773952338737e-24
# 1.2442733689971067e-26
# 5.7037022058170264e-27
# The best matching document is document 1 with a probability of 1.852773952338737e-24
#
# Query: ['<s>', 'the', 'cemetery', 'of', 'saint', 'michel', 'contains', 'graves', 'of', 'several', 'notable', 'bretons', 'and', 'sculptures', 'by', 'paul', 'le', 'goff', 'and', 'jean', 'boucher', '</s>']
# 7.872153778633046e-36
# 2.8039846946778033e-41
# 4.5132583839429705e-40
# The best matching document is document 1 with a probability of 7.872153778633046e-36
#
# Query: ['<s>', 'outside', 'the', 'wall', 'is', 'armel', 'beaufils', 'statue', 'of', 'anatole', 'le', 'braz', '</s>']
# 4.743101317987167e-20
# 2.36688272486815e-22
# 2.9202955293783135e-22
# The best matching document is document 1 with a probability of 4.743101317987167e-20
#
# Query: ['<s>', 'le', 'goff', 'who', 'was', 'killed', 'with', 'his', 'two', 'brothers', 'in', 'world', 'war', 'i', 'is', 'also', 'commemorated', 'in', 'a', 'street', 'and', 'with', 'his', 'major', 'sculptural', 'work', 'la', 'forme', 'se', 'gageant', 'de', 'la', 're', 'in', 'the', 'central', 'gardens', 'which', 'also', 'includes', 'a', 'memorial', 'to', 'him', 'by', 'jules-charles', 'le', 'bozec', 'and', 'work', 'by', 'francis', 'renaud', '</s>']
# 3.3600115159471584e-97
# 4.662000323627904e-109
# 3.9719675670022015e-108
# The best matching document is document 1 with a probability of 3.3600115159471584e-97
#
# Query: ['<s>', 'the', 'town', 'of', 'brieux', 'in', 'saskatchewan', 'canada', 'is', 'named', 'after', 'saint-brieuc', 'of', 'brittany', '</s>']
# 8.89331497122594e-23
# 3.639651098639075e-25
# 4.10666558818827e-25
# The best matching document is document 1 with a probability of 8.89331497122594e-23
#
# Query: ['<s>', 'it', 'was', 'founded', 'by', 'immigrants', 'from', 'this', 'region', 'in', 'brittany', '</s>']
# 5.186581291229829e-19
# 3.5068133128828125e-21
# 2.628367386450903e-22
# The best matching document is document 1 with a probability of 5.186581291229829e-19
#
# Query: ['<s>', 'it', 'was', 'settled', 'in', 'the', 'early', 'num', '</s>']
# 1.116328935276033e-11
# 6.877533326964859e-14
# 2.1961294673334225e-14
# The best matching document is document 1 with a probability of 1.116328935276033e-11
#
# Query: ['<s>', 'the', 'town', 'is', 'located', 'by', 'the', 'english', 'channel', 'in', 'the', 'bay', 'of', 'saint-brieuc', '</s>']
# 1.5195062376618087e-21
# 7.7645890104312e-24
# 1.8480708109624082e-23
# The best matching document is document 1 with a probability of 1.5195062376618087e-21
#
# Query: ['<s>', 'two', 'rivers', 'flow', 'through', 'saint-brieuc', 'the', 't', 'and', 'the', 'dic', '</s>']
# 1.2806373558565358e-17
# 4.891557631394967e-20
# 1.8284294786719455e-19
# The best matching document is document 1 with a probability of 1.2806373558565358e-17
#
# Query: ['<s>', 'other', 'towns', 'of', 'notable', 'size', 'in', 'the', 'partement', 'of', 'tes', 'are', 'dinan', 'and', 'all', 'sous-pr', 'fectures', '</s>']
# 3.3887040737791266e-28
# 2.4120300446303548e-32
# 1.7328287824855915e-31
# The best matching document is document 1 with a probability of 3.3887040737791266e-28
#
# Query: ['<s>', 'in', 'num', 'large', 'amounts', 'of', 'sea', 'lettuce', 'a', 'type', 'of', 'algae', 'washed', 'up', 'on', 'many', 'beaches', 'of', 'brittany', 'and', 'when', 'it', 'rotted', 'it', 'emitted', 'dangerous', 'levels', 'of', 'hydrogen', 'sulphide', '</s>']
# 6.429186703444105e-51
# 3.7857245785476883e-60
# 4.419967907612257e-59
# The best matching document is document 1 with a probability of 6.429186703444105e-51
#
# Query: ['<s>', 'a', 'horse', 'and', 'some', 'dogs', 'died', 'and', 'a', 'council', 'worker', 'driving', 'a', 'truckload', 'of', 'it', 'fell', 'unconscious', 'at', 'the', 'wheel', 'and', 'died', '</s>']
# 8.302662188402042e-40
# 3.193926251863212e-45
# 3.725421532253706e-43
# The best matching document is document 1 with a probability of 8.302662188402042e-40
#
# Query: ['<s>', 'the', 'beach', 'at', 'saint-brieuc', 'suffered', 'bad', 'damage', 'and', 'had', 'to', 'be', 'shut', '</s>']
# 1.927796095305458e-22
# 5.0900703760606e-25
# 2.1426907953186002e-24
# The best matching document is document 1 with a probability of 1.927796095305458e-22
#
# Query: ['<s>', 'langueux', 'la', 'augon', 'rin', 'ploufragan', 'gueux', 'and', 'muson', '</s>']
# 8.196079077481824e-16
# 4.5315695619587626e-18
# 1.1701948663499947e-17
# The best matching document is document 1 with a probability of 8.196079077481824e-16
#
# Query: ['<s>', 'inhabitants', 'of', 'saint-brieuc', 'are', 'called', 'briochins', 'or', 'briochains', '</s>']
# 2.4895590197861244e-15
# 5.508734629519732e-17
# 3.0658459835230144e-17
# The best matching document is document 1 with a probability of 2.4895590197861244e-15
#
# Query: ['<s>', 'in', 'num', 'of', 'the', 'children', 'attended', 'the', 'bilingual', 'schools', 'in', 'primary', 'education', '</s>']
# 9.724839921035615e-20
# 5.568900997166744e-23
# 1.4784566487747376e-22
# The best matching document is document 1 with a probability of 9.724839921035615e-20
#
# Query: ['<s>', 'the', 'gare', 'de', 'saint-brieuc', 'railway', 'station', 'is', 'connected', 'by', 'tgv', 'atlantique', 'to', 'paris', 'montparnasse', 'station', '</s>']
# 1.8364160334795174e-28
# 2.7515009398005525e-31
# 2.9338900020920073e-31
# The best matching document is document 1 with a probability of 1.8364160334795174e-28
#
# Query: ['<s>', 'an', 'air', 'service', 'from', 'saint-brieuc', 'armor', 'airport', 'to', 'newquay', 'in', 'cornwall', 'is', 'operated', 'by', 'isles', 'of', 'scilly', 'skybus', 'four', 'days', 'per', 'week', '</s>']
# 1.9997342322392537e-41
# 4.376667057249435e-46
# 1.8951391064237702e-46
# The best matching document is document 1 with a probability of 1.9997342322392537e-41
#
# Query: ['<s>', 'bourseul', 'gallo', 'rsoeut', 'is', 'a', 'commune', 'in', 'the', 'tes-d', 'armor', 'department', 'in', 'bretagne', 'in', 'north-western', 'france', '</s>']
# 1.8826133743217368e-29
# 2.4276925773876947e-32
# 5.867780004184015e-32
# The best matching document is document 1 with a probability of 1.8826133743217368e-29
#
# Query: ['<s>', 'inhabitants', 'of', 'bourseul', 'are', 'called', 'bourseulais', '</s>']
# 1.633399673186483e-11
# 3.2873374206526316e-13
# 3.9488096571938723e-13
# The best matching document is document 1 with a probability of 1.633399673186483e-11
#
# Query: ['<s>', 'stoke', 'by', 'nayland', 'in', 'the', 'english', 'county', 'of', 'suffolk', 'lies', 'close', 'to', 'the', 'border', 'with', 'essex', 'in', 'what', 'is', 'sometimes', 'referred', 'to', 'as', 'constable', 'country', '</s>']
# 3.8575120220664605e-45
# 1.2430919639128684e-49
# 8.994854878712878e-49
# The best matching document is document 1 with a probability of 3.8575120220664605e-45
#
# Query: ['<s>', 'it', 'contains', 'a', 'church', 'st', 'mary', 'part', 'of', 'the', 'deanery', 'of', 'hadleigh', 'in', 'the', 'diocese', 'of', 'chelmsford', '</s>']
# 2.573297156026023e-28
# 1.5231938586409553e-32
# 1.6918940869305862e-31
# The best matching document is document 1 with a probability of 2.573297156026023e-28
#
# Query: ['<s>', 'the', 'incumbent', 'is', 'the', 'revd', '</s>']
# 2.2326565788896347e-08
# 8.752605388603215e-09
# 1.1302404674916085e-08
# The best matching document is document 1 with a probability of 2.2326565788896347e-08
#
# Query: ['<s>', 'v', 'armstrong', '</s>']
# 0.000114312314271
# 3.121795335389787e-05
# 2.8934540465758323e-05
# The best matching document is document 1 with a probability of 0.000114312314271
#
# Query: ['<s>', 'the', 'village', 'located', 'within', 'babergh', 'district', 'contains', 'many', 'cottages', 'and', 'timber', 'framed', 'houses', 'and', 'all', 'surround', 'a', 'large', 'recreation', 'field', 'which', 'makes', 'up', 'the', 'center', 'of', 'the', 'village', '</s>']
# 7.168977208863756e-50
# 7.27549788227611e-57
# 2.716249139383113e-55
# The best matching document is document 1 with a probability of 7.168977208863756e-50
#
# Query: ['<s>', 'the', 'population', 'of', 'the', 'stoke-by-nayland', 'civil', 'parish', 'at', 'the', 'num', 'census', 'was', 'num', 'comprising', 'num', 'males', 'and', 'num', 'females', '</s>']
# 2.8592190622511384e-30
# 3.7087370894938425e-37
# 4.759540014352698e-37
# The best matching document is document 1 with a probability of 2.8592190622511384e-30
#
# Query: ['<s>', 'two', 'schools', 'a', 'primary', 'and', 'a', 'middle', 'school', 'are', 'in', 'the', 'village', 'as', 'are', 'two', 'public', 'houses', 'the', 'angel', 'inn', 'and', 'the', 'crown', '</s>']
# 8.648606446252127e-41
# 6.551370892479462e-46
# 3.966884038973855e-44
# The best matching document is document 1 with a probability of 8.648606446252127e-41
#
# Query: ['<s>', 'stoke', 'by', 'nayland', 'is', 'about', 'miles', 'from', 'nayland', 'and', 'stands', 'on', 'a', 'ridge', 'overlooking', 'the', 'stour', 'and', 'box', 'valleys', '</s>']
# 3.5867500653896823e-35
# 2.935202255831031e-39
# 1.0832238015757947e-38
# The best matching document is document 1 with a probability of 3.5867500653896823e-35
#
# Query: ['<s>', 'immediately', 'to', 'the', 'north', 'of', 'the', 'village', 'lies', 'the', 'hamlet', 'of', 'scotland', 'street', '</s>']
# 4.446657485612969e-21
# 1.542898977556412e-23
# 6.198498372171647e-23
# The best matching document is document 1 with a probability of 4.446657485612969e-21
#
# Query: ['<s>', 'st', 'mary', 'church', 'was', 'rebuilt', 'in', 'the', 'fifteenth', 'century', 'and', 'renovated', 'in', 'num', '</s>']
# 8.003983474103347e-23
# 2.994032794150005e-26
# 7.231860430398285e-26
# The best matching document is document 1 with a probability of 8.003983474103347e-23
#
# Query: ['<s>', 'the', 'church', 'is', 'on', 'the', 'site', 'of', 'a', 'num', 'century', 'minster', '</s>']
# 1.9692800857734757e-18
# 7.722532583730503e-21
# 1.8076217706063145e-20
# The best matching document is document 1 with a probability of 1.9692800857734757e-18
#
# Query: ['<s>', 'a', 'saxon', 'monastery', 'was', 'founded', 'here', 'during', 'the', 'time', 'of', 'king', 'edmund', 'by', 'earl', 'alfgar', 'who', 'died', 'in', 'num', '</s>']
# 4.467529784767405e-34
# 4.3461762767505975e-39
# 2.00202970469812e-39
# The best matching document is document 1 with a probability of 4.467529784767405e-34
#
# Query: ['<s>', 'the', 'num', 'national', 'gazetteer', 'of', 'great', 'britain', 'describes', 'the', 'village', 'such', '</s>']
# 1.9209560337848036e-18
# 9.467530899477422e-22
# 1.4692736882189474e-21
# The best matching document is document 1 with a probability of 1.9209560337848036e-18
#
# Query: ['<s>', 'stoke-by-nayland', 'a', 'parish', 'in', 'the', 'hundred', 'of', 'babergh', 'county', 'suffolk', 'num', 'mile', 'of', 'nayland', 'and', 'num', 'miles', 'of', 'bures', 'railway', 'station', '</s>']
# 9.684225176552143e-36
# 3.2773847080649653e-42
# 4.406641469580101e-41
# The best matching document is document 1 with a probability of 9.684225176552143e-36
#
# Query: ['<s>', 'colchester', 'is', 'its', 'post', 'town', '</s>']
# 2.1778662595021402e-10
# 3.3969155930498415e-11
# 2.80804269111199e-11
# The best matching document is document 1 with a probability of 2.1778662595021402e-10
#
# Query: ['<s>', 'the', 'village', 'which', 'was', 'formerly', 'a', 'market', 'town', 'is', 'situated', 'near', 'the', 'river', 'stour', '</s>']
# 3.049833666401213e-25
# 1.3825259655523409e-27
# 9.506170343028368e-28
# The best matching document is document 1 with a probability of 3.049833666401213e-25
#
# Query: ['<s>', 'the', 'parish', 'contains', 'the', 'chapelry', 'of', 'leavenheath', 'and', 'had', 'a', 'monastery', 'endowed', 'by', 'the', 'saxon', 'earl', 'of', 'algar', 'traces', 'of', 'which', 'are', 'still', 'existing', '</s>']
# 5.765737630834751e-41
# 7.657446497703264e-47
# 2.1516804050684083e-45
# The best matching document is document 1 with a probability of 5.765737630834751e-41
#
# Query: ['<s>', 'the', 'living', 'is', 'a', 'vicarage', 'in', 'the', 'diocese', 'of', 'ely', 'value', 'num', '</s>']
# 4.9232002100274324e-20
# 1.494683384825429e-22
# 4.463091008791581e-22
# The best matching document is document 1 with a probability of 4.9232002100274324e-20
#
# Query: ['<s>', 'the', 'church', 'dedicated', 'to', 'mary', 'is', 'an', 'ancient', 'structure', 'with', 'a', 'tower', 'and', 'six', 'bells', '</s>']
# 3.765226748643473e-28
# 1.114940294800275e-30
# 6.238424287612367e-30
# The best matching document is document 1 with a probability of 3.765226748643473e-28
#
# Query: ['<s>', 'there', 'is', 'also', 'a', 'district', 'church', 'at', 'leavenheath', 'the', 'living', 'of', 'which', 'is', 'a', 'perpetual', 'curacy', 'value', 'num', '</s>']
# 8.824750192133143e-33
# 1.8080845895919197e-36
# 7.832842995049013e-36
# The best matching document is document 1 with a probability of 8.824750192133143e-33
#
# Query: ['<s>', 'the', 'parochial', 'charities', 'produce', 'about', 'num', 'per', 'annum', 'exclusive', 'of', 'some', 'almshouses', '</s>']
# 4.743101317987167e-21
# 3.8175527820454026e-25
# 4.534620387233408e-25
# The best matching document is document 1 with a probability of 4.743101317987167e-21
#
# Query: ['<s>', 'num', 'go', 'towards', 'lady', 'windsor', 'hospital', '</s>']
# 1.0754894965479627e-11
# 5.408428272995213e-14
# 4.333231590891463e-14
# The best matching document is document 1 with a probability of 1.0754894965479627e-11
#
# Query: ['<s>', 'there', 'is', 'a', 'national', 'school', 'for', 'both', 'sexes', '</s>']
# 4.14926509528639e-16
# 1.8362454995847377e-17
# 2.0312029309687357e-17
# The best matching document is document 1 with a probability of 4.14926509528639e-16
#
# Query: ['<s>', 'tendring', 'hall', 'is', 'the', 'principal', 'residence', '</s>']
# 2.722332788226139e-11
# 3.506493217023305e-12
# 3.488251430936962e-12
# The best matching document is document 1 with a probability of 2.722332788226139e-11
#
# Query: ['<s>', 'the', 'birthstone', 'of', 'april', 'is', 'the', 'diamond', 'and', 'the', 'birth', 'flower', 'is', 'typically', 'listed', 'as', 'either', 'the', 'daisy', 'or', 'the', 'sweet', 'pea', '</s>']
# 2.1016113664392675e-36
# 8.481775255492714e-40
# 9.38022814635134e-39
# The best matching document is document 1 with a probability of 2.1016113664392675e-36
